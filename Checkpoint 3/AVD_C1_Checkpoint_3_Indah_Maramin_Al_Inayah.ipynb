# %% [markdown]
# Nama: Indah Maramin Al Inayah
#
# Nim: 2409116086

# %% [markdown]
# # **Studi Kasus: Analisis Variasi Shade dan Brand pada Produk Makeup**

# %% [markdown]
# ## **Latar Belakang**

# %% [markdown]
# Industri kosmetik merupakan salah satu sektor yang terus berkembang seiring dengan meningkatnya kesadaran masyarakat terhadap perawatan diri dan penampilan. Salah satu aspek penting dalam produk kosmetik adalah variasi shade makeup yang ditawarkan, terutama pada produk seperti foundation, lipstik, dan bedak. Variasi shade yang beragam memungkinkan konsumen memilih produk sesuai dengan warna kulit dan preferensi pribadi. Analisis data terhadap shade makeup dapat membantu perusahaan kosmetik memahami tren pasar dan kebutuhan konsumen, sehingga dapat memberikan penawaran produk yang lebih sesuai.

# %% [markdown]
# ## **Tujuan Studi Kasus**

# %% [markdown]
# Tujuan dari studi kasus ini adalah untuk menganalisis variasi shade makeup yang ditawarkan oleh berbagai merek kosmetik. Analisis ini bertujuan untuk:
# 1. Mengetahui tren shade makeup yang paling populer.
# 2. Menganalisis hubungan antara jumlah shade yang ditawarkan dan harga produk.
# 3. Mengidentifikasi merek kosmetik dengan variasi shade terbanyak.

# %% [markdown]
# ## **Business Understanding**

# %% [markdown]
# ### **Business Objective**

# %% [markdown]
# Tujuan utama dari analisis data adalah untuk memahami distribusi dan variasi shade makeup yang tersedia di berbagai merek kosmetik. Analisis ini diharapkan dapat membantu perusahaan kosmetik dalam mengetahui tren shade makeup yang paling populer dan variasi produk yang banyak diminati oleh konsumen. Selain itu, proyek ini juga bertujuan untuk memberikan wawasan terkait hubungan antara harga produk dengan jumlah shade yang ditawarkan oleh berbagai merek.

# %% [markdown]
# ### **Assess Situation**

# %% [markdown]
# Situasi saat ini menunjukkan bahwa dataset yang digunakan berisi informasi tentang produk makeup seperti merek, kategori, shade, dan harga. Tantangan yang mungkin dihadapi adalah adanya data yang tidak lengkap atau duplikasi yang perlu dibersihkan sebelum analisis dilakukan. Selain itu, perlu dilakukan pemrosesan data lebih lanjut agar data siap digunakan dalam proses analisis.

# %% [markdown]
# ### **Data Mining Goals**

# %% [markdown]
# Data mining dalam proyek ini adalah untuk mengetahui merek kosmetik dengan variasi shade terbanyak, menganalisis distribusi harga produk di berbagai kategori, serta menemukan pola atau tren yang dapat membantu memahami preferensi konsumen terhadap shade makeup tertentu.

# %% [markdown]
# ### **Project Plan**

# %% [markdown]
# Rencana proyek ini dimulai dengan pembersihan data untuk memastikan kualitas data yang baik. Selanjutnya, dilakukan eksplorasi data dengan statistik deskriptif dan visualisasi untuk memahami distribusi data. Setelah itu, analisis lebih dalam dilakukan untuk mencapai tujuan yang telah ditetapkan. Hasil dari proyek ini akan didokumentasikan secara sistematis menggunakan Google Colaboratory dengan markdown untuk menjelaskan proses dan hasil analisis.

# %% [markdown]
# ## **Tampilan data secara keseluruhan**

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Pandas/shades.csv")
print(df)
# Out:
#           brand brand_short     product product_short     hex     H     S  \
# 0    Maybelline          mb      Fit Me           fmf  f3cfb3  26.0  0.26
# 1    Maybelline          mb      Fit Me           fmf  ffe3c2  32.0  0.24
# 2    Maybelline          mb      Fit Me           fmf  ffe0cd  23.0  0.20
# 3    Maybelline          mb      Fit Me           fmf  ffd3be  19.0  0.25
# 4    Maybelline          mb      Fit Me           fmf  bd9584  18.0  0.30
# ..          ...         ...         ...           ...     ...   ...   ...
# 620     L'Oréal          lo  True Match           tms  eecfba  24.0  0.22
# 621     L'Oréal          lo  True Match           tms  e8c7b8  19.0  0.21
# 622     L'Oréal          lo  True Match           tms  f0cbb9  20.0  0.23
# 623     L'Oréal          lo  True Match           tms  e9c4b1  20.0  0.24
# 624     L'Oréal          lo  True Match           tms  eabea1  24.0  0.31
#
#         V   L  group
# 0    0.95  86      2
# 1    1.00  92      2
# 2    1.00  91      2
# 3    1.00  88      2
# 4    0.74  65      2
# ..    ...  ..    ...
# 620  0.93  85      7
# 621  0.91  83      7
# 622  0.94  85      7
# 623  0.91  82      7
# 624  0.92  80      7
#
# [625 rows x 10 columns]

# %% [markdown]
# ### **Info data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brand          625 non-null    object
#  1   brand_short    625 non-null    object
#  2   product        625 non-null    object
#  3   product_short  625 non-null    object
#  4   hex            625 non-null    object
#  5   H              613 non-null    float64
#  6   S              613 non-null    float64
#  7   V              613 non-null    float64
#  8   L              625 non-null    int64
#  9   group          625 non-null    int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 49.0+ KB

# %% [markdown]
# ### **Tampilan 5 Baris Pertama**

# %%
df.head()
# Out:
#         brand brand_short product product_short     hex     H     S     V   L  \
# 0  Maybelline          mb  Fit Me           fmf  f3cfb3  26.0  0.26  0.95  86
# 1  Maybelline          mb  Fit Me           fmf  ffe3c2  32.0  0.24  1.00  92
# 2  Maybelline          mb  Fit Me           fmf  ffe0cd  23.0  0.20  1.00  91
# 3  Maybelline          mb  Fit Me           fmf  ffd3be  19.0  0.25  1.00  88
# 4  Maybelline          mb  Fit Me           fmf  bd9584  18.0  0.30  0.74  65
#
#    group
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2

# %% [markdown]
# ### **Tampilan 5 Baris Akhir**

# %%
df.tail()
# Out:
#        brand brand_short     product product_short     hex     H     S     V  \
# 620  L'Oréal          lo  True Match           tms  eecfba  24.0  0.22  0.93
# 621  L'Oréal          lo  True Match           tms  e8c7b8  19.0  0.21  0.91
# 622  L'Oréal          lo  True Match           tms  f0cbb9  20.0  0.23  0.94
# 623  L'Oréal          lo  True Match           tms  e9c4b1  20.0  0.24  0.91
# 624  L'Oréal          lo  True Match           tms  eabea1  24.0  0.31  0.92
#
#       L  group
# 620  85      7
# 621  83      7
# 622  85      7
# 623  82      7
# 624  80      7

# %% [markdown]
# ### **Tampilan Tipe Data**

# %%
df.dtypes
# Out:
# brand             object
# brand_short       object
# product           object
# product_short     object
# hex               object
# H                float64
# S                float64
# V                float64
# L                  int64
# group              int64
# dtype: object

# %% [markdown]
# ## **Pengecekan Struktur Data**

# %%
kolom_tertentu = "brand"
if kolom_tertentu in df.columns:
    print(f"\nMenghitung jumlah kemunculan nilai unik dalam kolom '{kolom_tertentu}' dengan df['{kolom_tertentu}'].value_counts():")
    print(df[kolom_tertentu].value_counts())
else:
    print(f"\nKolom '{kolom_tertentu}' tidak ditemukan dalam dataset.")
# Out:
# Menghitung jumlah kemunculan nilai unik dalam kolom 'brand' dengan df['brand'].value_counts():
# brand
# Maybelline          54
# Estée Lauder        42
# MAC                 42
# Make Up For Ever    40
# Fenty               40
# Lancôme             40
# L'Oréal             36
# Beauty Bakerie      30
# Bobbi Brown         30
# bareMinerals        29
# Revlon              22
# Black Up            18
# Addiction           17
# Laws of Nature      17
# NARS                13
# Trim & Prissy       13
# Black Opal          12
# Covergirl + Olay    12
# House of Tara       11
# Elsas Pro           11
# Shu Uemera          11
# Hegai and Ester     10
# RMK                  9
# Iman                 8
# Bharat & Doris       7
# Dior                 6
# IPSA                 6
# Kate                 6
# Shiseido             6
# Kuddy                5
# Nykaa                5
# Lakmé                4
# Olivia               4
# Lotus Herbals        4
# Colorbar             3
# Blue Heaven          2
# Name: count, dtype: int64

# %% [markdown]
# Beberapa brand makeup mendominasi dataset dengan frekuensi tinggi, sementara brand lainnya memiliki kemunculan lebih rendah. Hal ini menggambarkan popularitas brand tertentu dan keragaman produk dalam industri makeup.

# %% [markdown]
# ### **Menghitung Rata-rata**

# %%
print("\nMenghitung rata-rata dengan df.mean():")
print(df.mean(numeric_only=True))
# Out:
# Menghitung rata-rata dengan df.mean():
# H        25.314845
# S         0.459494
# V         0.779543
# L        65.920000
# group     3.472000
# dtype: float64

# %% [markdown]
# Rata-rata nilai dari kolom numerik dalam dataset. Rata-rata tersebut memberikan gambaran umum tentang kecenderungan data, seperti jumlah rata-rata warna atau tingkat kecerahan produk makeup, yang membantu memahami distribusi data secara keseluruhan.

# %% [markdown]
# ### **Menghitung Median**

# %%
print("\nMenghitung median dengan df.median():")
print(df.median(numeric_only=True))

# %% [markdown]
# Median dari kolom numerik dalam dataset, yang menunjukkan nilai tengah dari data. Median membantu memahami persebaran data dan memberikan gambaran yang lebih akurat terhadap kecenderungan data tanpa terpengaruh oleh nilai ekstrem.

# %% [markdown]
# ### **Menghitung Standar Deviasi**

# %%
print("\nMenghitung standar deviasi dengan df.std():")
print(df.std(numeric_only=True))
# Out:
# Menghitung standar deviasi dengan df.std():
# H         5.327852
# S         0.154089
# V         0.173955
# L        17.512267
# group     1.976529
# dtype: float64

# %% [markdown]
# Standar deviasi dari kolom numerik dalam dataset, yang menggambarkan seberapa besar variasi atau penyebaran data dari nilai rata-rata. Semakin besar nilai standar deviasi, semakin beragam data, sedangkan nilai yang kecil menunjukkan data cenderung mendekati rata-rata.

# %% [markdown]
# ### **Menghitung Korelasi Antar Kolom Numerik**

# %%
print("\nMenghitung korelasi antar kolom numerik dengan df.corr():")
print(df.corr(numeric_only=True))
# Out:
# Menghitung korelasi antar kolom numerik dengan df.corr():
#               H         S         V         L     group
# H      1.000000 -0.166436  0.409831  0.451416  0.118561
# S     -0.166436  1.000000 -0.707797 -0.810619 -0.048267
# V      0.409831 -0.707797  1.000000  0.980690  0.165535
# L      0.451416 -0.810619  0.980690  1.000000  0.132859
# group  0.118561 -0.048267  0.165535  0.132859  1.000000

# %% [markdown]
# Korelasi antar kolom numerik dalam dataset, yang menunjukkan hubungan linier antara dua variabel. Nilai korelasi berkisar antara -1 hingga 1, di mana nilai mendekati 1 menunjukkan hubungan positif kuat, mendekati -1 menunjukkan hubungan negatif kuat, dan mendekati 0 menunjukkan hubungan yang lemah atau tidak ada korelasi.

# %% [markdown]
# ### **Visualisasi Jumlah Data Per Brand**

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
brand_counts = df['brand'].value_counts()
plt.bar(brand_counts.index, brand_counts.values, color='skyblue')
plt.title('Jumlah Produk per Brand')
plt.xlabel('Brand')
plt.ylabel('Jumlah Produk')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Visualisasi ini menampilkan diagram batang yang menunjukkan jumlah produk untuk setiap brand dalam dataset. Diagram ini membantu memahami distribusi produk berdasarkan brand, di mana brand dengan batang lebih tinggi menunjukkan jumlah produk yang lebih banyak, sedangkan batang lebih pendek menunjukkan brand dengan jumlah produk lebih sedikit.

# %% [markdown]
# ### **Visualisasi distribusi hue (H)**

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['H'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title('Distribusi Hue (H)')
plt.xlabel('Hue')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# Visualisasi ini berupa histogram yang menunjukkan distribusi nilai Hue (H) dalam dataset. Histogram digunakan untuk menggambarkan sebaran frekuensi data numerik. Grafik ini membantu melihat pola sebaran warna dominan pada produk makeup.

# %% [markdown]
# ### **Visualisasi hubungan antara hue dan brightness (V)**

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['H'], df['V'], c='blue', alpha=0.5)
plt.title('Hubungan antara Hue dan Brightness')
plt.xlabel('Hue')
plt.ylabel('Brightness')
plt.show()

# %% [markdown]
# Visualisasi ini berupa scatter plot yang menunjukkan hubungan antara nilai Hue (H) dan Brightness (V) dalam dataset. Setiap titik merepresentasikan satu produk makeup, di mana posisi titik menunjukkan nilai Hue dan Brightness. Grafik ini membantu melihat pola hubungan antara kedua variabel, seperti apakah terdapat korelasi atau pola tertentu pada distribusi warna produk.

# %% [markdown]
# **Checkpoint 2**

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Sumber Data**

# %% [markdown]
# Dataset yang digunakan dalam analisis ini adalah "Makeup Shades Dataset" yang diperoleh dari Kaggle. Dataset ini berisi informasi mengenai merek kosmetik, produk, dan variasi shade makeup yang tersedia.
#
# Sumber dataset: https://www.kaggle.com/datasets/shivamb/makeup-shades-dataset

# %% [markdown]
# ## **Struktur Data**

# %% [markdown]
# Dataset ini memiliki beberapa kolom utama, antara lain:
#
# * brand: Nama merek kosmetik.
#
# * brand_short: Singkatan dari nama merek.
#
# * product: Nama produk kosmetik.
#
# * product_short: Singkatan dari nama produk.
#
# * h: Nilai hue dari shade makeup.
#
# * s: Nilai saturation dari shade makeup.
#
# * v: Nilai brightness dari shade makeup.
#
# * l: Nilai lightness dari shade makeup.
#
# * group: Kategori produk kosmetik.

# %% [markdown]
# ## **Informasi Data**

# %%
df = pd.read_csv("/content/drive/MyDrive/Pandas/shades.csv")
print(df)
# Out:
#           brand brand_short     product product_short     hex     H     S  \
# 0    Maybelline          mb      Fit Me           fmf  f3cfb3  26.0  0.26
# 1    Maybelline          mb      Fit Me           fmf  ffe3c2  32.0  0.24
# 2    Maybelline          mb      Fit Me           fmf  ffe0cd  23.0  0.20
# 3    Maybelline          mb      Fit Me           fmf  ffd3be  19.0  0.25
# 4    Maybelline          mb      Fit Me           fmf  bd9584  18.0  0.30
# ..          ...         ...         ...           ...     ...   ...   ...
# 620     L'Oréal          lo  True Match           tms  eecfba  24.0  0.22
# 621     L'Oréal          lo  True Match           tms  e8c7b8  19.0  0.21
# 622     L'Oréal          lo  True Match           tms  f0cbb9  20.0  0.23
# 623     L'Oréal          lo  True Match           tms  e9c4b1  20.0  0.24
# 624     L'Oréal          lo  True Match           tms  eabea1  24.0  0.31
#
#         V   L  group
# 0    0.95  86      2
# 1    1.00  92      2
# 2    1.00  91      2
# 3    1.00  88      2
# 4    0.74  65      2
# ..    ...  ..    ...
# 620  0.93  85      7
# 621  0.91  83      7
# 622  0.94  85      7
# 623  0.91  82      7
# 624  0.92  80      7
#
# [625 rows x 10 columns]

# %% [markdown]
# ## **Missing Values**

# %% [markdown]
# Melakukan pengecekan missing values perkolom dalam bentuk presentase, guna mendukung pengambilan keputusan pada nilai yang kosong

# %% [markdown]
# ### **Melihat Missing Values**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# brand            0.00
# brand_short      0.00
# product          0.00
# product_short    0.00
# hex              0.00
# H                1.92
# S                1.92
# V                1.92
# L                0.00
# group            0.00
# dtype: float64

# %% [markdown]
# **Melakukan pengecekan nilai kosong pada kolom 'H'**

# %%
df[df['H'].isnull()]
# Out:
#                 brand brand_short         product product_short     hex   H  \
# 155  Covergirl + Olay          oc  Simply Ageless            sa  e1ad81 NaN
# 156  Covergirl + Olay          oc  Simply Ageless            sa  deb192 NaN
# 157  Covergirl + Olay          oc  Simply Ageless            sa  e3b490 NaN
# 158  Covergirl + Olay          oc  Simply Ageless            sa  e9b898 NaN
# 159  Covergirl + Olay          oc  Simply Ageless            sa  e8bb9c NaN
# 160  Covergirl + Olay          oc  Simply Ageless            sa  e1b7a0 NaN
# 161  Covergirl + Olay          oc  Simply Ageless            sa  eac4ae NaN
# 162  Covergirl + Olay          oc  Simply Ageless            sa  eac7ab NaN
# 163  Covergirl + Olay          oc  Simply Ageless            sa  eabe9e NaN
# 164  Covergirl + Olay          oc  Simply Ageless            sa  e5b39a NaN
# 165  Covergirl + Olay          oc  Simply Ageless            sa  e7b590 NaN
# 166  Covergirl + Olay          oc  Simply Ageless            sa  f7dcca NaN
#
#       S   V   L  group
# 155 NaN NaN  75      2
# 156 NaN NaN  76      2
# 157 NaN NaN  77      2
# 158 NaN NaN  79      2
# 159 NaN NaN  79      2
# 160 NaN NaN  78      2
# 161 NaN NaN  82      2
# 162 NaN NaN  83      2
# 163 NaN NaN  80      2
# 164 NaN NaN  77      2
# 165 NaN NaN  78      2
# 166 NaN NaN  90      2

# %% [markdown]
# **Melakukan pengecekan nilai kosong pada kolom 'S'**

# %%
df[df['S'].isnull()]
# Out:
#                 brand brand_short         product product_short     hex   H  \
# 155  Covergirl + Olay          oc  Simply Ageless            sa  e1ad81 NaN
# 156  Covergirl + Olay          oc  Simply Ageless            sa  deb192 NaN
# 157  Covergirl + Olay          oc  Simply Ageless            sa  e3b490 NaN
# 158  Covergirl + Olay          oc  Simply Ageless            sa  e9b898 NaN
# 159  Covergirl + Olay          oc  Simply Ageless            sa  e8bb9c NaN
# 160  Covergirl + Olay          oc  Simply Ageless            sa  e1b7a0 NaN
# 161  Covergirl + Olay          oc  Simply Ageless            sa  eac4ae NaN
# 162  Covergirl + Olay          oc  Simply Ageless            sa  eac7ab NaN
# 163  Covergirl + Olay          oc  Simply Ageless            sa  eabe9e NaN
# 164  Covergirl + Olay          oc  Simply Ageless            sa  e5b39a NaN
# 165  Covergirl + Olay          oc  Simply Ageless            sa  e7b590 NaN
# 166  Covergirl + Olay          oc  Simply Ageless            sa  f7dcca NaN
#
#       S   V   L  group
# 155 NaN NaN  75      2
# 156 NaN NaN  76      2
# 157 NaN NaN  77      2
# 158 NaN NaN  79      2
# 159 NaN NaN  79      2
# 160 NaN NaN  78      2
# 161 NaN NaN  82      2
# 162 NaN NaN  83      2
# 163 NaN NaN  80      2
# 164 NaN NaN  77      2
# 165 NaN NaN  78      2
# 166 NaN NaN  90      2

# %% [markdown]
# **Melakukan pengecekan nilai kosong pada kolom 'V'**

# %%
df[df['V'].isnull()]
# Out:
#                 brand brand_short         product product_short     hex   H  \
# 155  Covergirl + Olay          oc  Simply Ageless            sa  e1ad81 NaN
# 156  Covergirl + Olay          oc  Simply Ageless            sa  deb192 NaN
# 157  Covergirl + Olay          oc  Simply Ageless            sa  e3b490 NaN
# 158  Covergirl + Olay          oc  Simply Ageless            sa  e9b898 NaN
# 159  Covergirl + Olay          oc  Simply Ageless            sa  e8bb9c NaN
# 160  Covergirl + Olay          oc  Simply Ageless            sa  e1b7a0 NaN
# 161  Covergirl + Olay          oc  Simply Ageless            sa  eac4ae NaN
# 162  Covergirl + Olay          oc  Simply Ageless            sa  eac7ab NaN
# 163  Covergirl + Olay          oc  Simply Ageless            sa  eabe9e NaN
# 164  Covergirl + Olay          oc  Simply Ageless            sa  e5b39a NaN
# 165  Covergirl + Olay          oc  Simply Ageless            sa  e7b590 NaN
# 166  Covergirl + Olay          oc  Simply Ageless            sa  f7dcca NaN
#
#       S   V   L  group
# 155 NaN NaN  75      2
# 156 NaN NaN  76      2
# 157 NaN NaN  77      2
# 158 NaN NaN  79      2
# 159 NaN NaN  79      2
# 160 NaN NaN  78      2
# 161 NaN NaN  82      2
# 162 NaN NaN  83      2
# 163 NaN NaN  80      2
# 164 NaN NaN  77      2
# 165 NaN NaN  78      2
# 166 NaN NaN  90      2

# %% [markdown]
# ### **Mengatasi Missing Values**

# %%
df['H'] = df['H'].fillna(df['H'].dropna().mean())
df['S'] = df['S'].fillna(df['S'].dropna().mean())
df['V'] = df['V'].fillna(df['V'].dropna().mean())

# %%
print(df[['H', 'S', 'V']].isnull().sum())
# Out:
# H    0
# S    0
# V    0
# dtype: int64

# %% [markdown]
# ## **Duplicated Values**

# %% [markdown]
# Duplicated Values adalah sebuah kondisi dimana ada data yang muncul beberapa kali dalam satu data set.

# %%
df[df.duplicated()]
# Out:
#               brand brand_short       product product_short     hex     H  \
# 123          Revlon          rv     ColorStay            cs  d5a187  20.0
# 223  Beauty Bakerie          bb   #1 CAKE MIX            cm  a4683b  26.0
# 492           Kuddy          ku    Matte Wear           mwf  c78660  22.0
# 609      Maybelline          mb  Fit Me Matte           fmm  ebba8a  30.0
#
#         S     V   L  group
# 123  0.37  0.84  71      2
# 223  0.64  0.64  50      3
# 492  0.52  0.78  62      5
# 609  0.41  0.92  79      7

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#           brand brand_short     product product_short     hex     H     S  \
# 0    Maybelline          mb      Fit Me           fmf  f3cfb3  26.0  0.26
# 1    Maybelline          mb      Fit Me           fmf  ffe3c2  32.0  0.24
# 2    Maybelline          mb      Fit Me           fmf  ffe0cd  23.0  0.20
# 3    Maybelline          mb      Fit Me           fmf  ffd3be  19.0  0.25
# 4    Maybelline          mb      Fit Me           fmf  bd9584  18.0  0.30
# ..          ...         ...         ...           ...     ...   ...   ...
# 620     L'Oréal          lo  True Match           tms  eecfba  24.0  0.22
# 621     L'Oréal          lo  True Match           tms  e8c7b8  19.0  0.21
# 622     L'Oréal          lo  True Match           tms  f0cbb9  20.0  0.23
# 623     L'Oréal          lo  True Match           tms  e9c4b1  20.0  0.24
# 624     L'Oréal          lo  True Match           tms  eabea1  24.0  0.31
#
#         V   L  group
# 0    0.95  86      2
# 1    1.00  92      2
# 2    1.00  91      2
# 3    1.00  88      2
# 4    0.74  65      2
# ..    ...  ..    ...
# 620  0.93  85      7
# 621  0.91  83      7
# 622  0.94  85      7
# 623  0.91  82      7
# 624  0.92  80      7
#
# [621 rows x 10 columns]

# %% [markdown]
# ## **Outliers**

# %% [markdown]
# Outliers adalah nilai yang jauh berbeda dari nilai lainnya dalam dataset. Nilai Outlier bisa jauh lebih rendah atau lebih tinggi. Outlier bisa terjadi karena berbagai alasan seperti faktor kesalahan maupun kejadian lain yang tidak terduga.

# %% [markdown]
# **Melakukan pengecekan outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom  Persentase Outliers
# H                 3.220612
# S                 0.805153
# V                 2.254428
# L                 0.805153
# group             0.000000

# %% [markdown]
# **Melakukan Imputasi**

# %%
columns_to_impute = ["H", "S", "V", "L"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# **Melakukan pengecekan ulang**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom  Persentase Outliers
# H                      0.0
# S                      0.0
# V                      0.0
# L                      0.0
# group                  0.0

# %%
df
# Out:
#           brand brand_short     product product_short     hex     H     S  \
# 0    Maybelline          mb      Fit Me           fmf  f3cfb3  26.0  0.26
# 1    Maybelline          mb      Fit Me           fmf  ffe3c2  32.0  0.24
# 2    Maybelline          mb      Fit Me           fmf  ffe0cd  23.0  0.20
# 3    Maybelline          mb      Fit Me           fmf  ffd3be  19.0  0.25
# 4    Maybelline          mb      Fit Me           fmf  bd9584  18.0  0.30
# ..          ...         ...         ...           ...     ...   ...   ...
# 620     L'Oréal          lo  True Match           tms  eecfba  24.0  0.22
# 621     L'Oréal          lo  True Match           tms  e8c7b8  19.0  0.21
# 622     L'Oréal          lo  True Match           tms  f0cbb9  20.0  0.23
# 623     L'Oréal          lo  True Match           tms  e9c4b1  20.0  0.24
# 624     L'Oréal          lo  True Match           tms  eabea1  24.0  0.31
#
#         V   L  group
# 0    0.95  86      2
# 1    1.00  92      2
# 2    1.00  91      2
# 3    1.00  88      2
# 4    0.74  65      2
# ..    ...  ..    ...
# 620  0.93  85      7
# 621  0.91  83      7
# 622  0.94  85      7
# 623  0.91  82      7
# 624  0.92  80      7
#
# [621 rows x 10 columns]

# %% [markdown]
# ## **Inconsistent Values**

# %%
df
# Out:
#           brand brand_short     product product_short     hex     H     S  \
# 0    Maybelline          mb      Fit Me           fmf  f3cfb3  26.0  0.26
# 1    Maybelline          mb      Fit Me           fmf  ffe3c2  32.0  0.24
# 2    Maybelline          mb      Fit Me           fmf  ffe0cd  23.0  0.20
# 3    Maybelline          mb      Fit Me           fmf  ffd3be  19.0  0.25
# 4    Maybelline          mb      Fit Me           fmf  bd9584  18.0  0.30
# ..          ...         ...         ...           ...     ...   ...   ...
# 620     L'Oréal          lo  True Match           tms  eecfba  24.0  0.22
# 621     L'Oréal          lo  True Match           tms  e8c7b8  19.0  0.21
# 622     L'Oréal          lo  True Match           tms  f0cbb9  20.0  0.23
# 623     L'Oréal          lo  True Match           tms  e9c4b1  20.0  0.24
# 624     L'Oréal          lo  True Match           tms  eabea1  24.0  0.31
#
#         V   L  group
# 0    0.95  86      2
# 1    1.00  92      2
# 2    1.00  91      2
# 3    1.00  88      2
# 4    0.74  65      2
# ..    ...  ..    ...
# 620  0.93  85      7
# 621  0.91  83      7
# 622  0.94  85      7
# 623  0.91  82      7
# 624  0.92  80      7
#
# [621 rows x 10 columns]

# %%
for col in ["brand", "product", "group"]:
    print(f"Nilai unik dalam {col}:")
    print(df[col].unique())
    print("\n")
# Out:
# Nilai unik dalam brand:
# ['Maybelline' 'bareMinerals' 'Estée Lauder' 'Revlon' "L'Oréal"
#  'Covergirl + Olay' 'Fenty' 'Iman' 'Beauty Bakerie' 'Black Up'
#  'Black Opal' 'Laws of Nature' 'Lancôme' 'MAC' 'Bobbi Brown'
#  'Make Up For Ever' 'Hegai and Ester' 'House of Tara' 'Trim & Prissy'
#  'Elsas Pro' 'Kuddy' 'RMK' 'Addiction' 'Shu Uemera' 'Shiseido' 'Kate'
#  'IPSA' 'Dior' 'NARS' 'Lakmé' 'Colorbar' 'Bharat & Doris' 'Olivia'
#  'Blue Heaven' 'Lotus Herbals' 'Nykaa']
#
#
# Nilai unik dalam product:
# ['Fit Me' 'barePRO' 'Double Wear' 'ColorStay' 'Infalliable'
#  'Simply Ageless' "PRO FILT'R" 'Second to None' '#1 CAKE MIX'
#  'Matifying Fluid' 'True Color' 'Foxy Finish' 'Teint Idole' 'Studio Fix'
#  'Skin Long-Wear' 'Ultra HD' 'Photo Perfect' 'Oil Free' 'Flawless Finish'
#  'Hi - Def' 'Full Coverage' 'Matte Wear' 'RMK Liquid' 'The Foundation'
#  'Petal Skin Fluid' 'Synchro Skin' 'Secret Skin Maker Zero'
#  'Liquid Foundation' 'Diorskin Forever' 'Velvet Matte' 'Invisible Finish'
#  'Perfect Match' 'Foundation' 'X Factor' 'Make-Up Ecostay' 'SKINgenius'
#  'Fit Me Matte' 'True Match']
#
#
# Nilai unik dalam group:
# [2 0 3 4 1 5 6 7]

# %%
df["product"] = df["product"].str.lower().str.strip()
df["product"] = df["product"].str.replace(r'[^a-z0-9\s]', '', regex=True)
df["product"] = df["product"].str.title()

# %%
df
# Out:
#           brand brand_short     product product_short     hex     H     S  \
# 0    Maybelline          mb      Fit Me           fmf  f3cfb3  26.0  0.26
# 1    Maybelline          mb      Fit Me           fmf  ffe3c2  32.0  0.24
# 2    Maybelline          mb      Fit Me           fmf  ffe0cd  23.0  0.20
# 3    Maybelline          mb      Fit Me           fmf  ffd3be  19.0  0.25
# 4    Maybelline          mb      Fit Me           fmf  bd9584  18.0  0.30
# ..          ...         ...         ...           ...     ...   ...   ...
# 620     L'Oréal          lo  True Match           tms  eecfba  24.0  0.22
# 621     L'Oréal          lo  True Match           tms  e8c7b8  19.0  0.21
# 622     L'Oréal          lo  True Match           tms  f0cbb9  20.0  0.23
# 623     L'Oréal          lo  True Match           tms  e9c4b1  20.0  0.24
# 624     L'Oréal          lo  True Match           tms  eabea1  24.0  0.31
#
#         V   L  group
# 0    0.95  86      2
# 1    1.00  92      2
# 2    1.00  91      2
# 3    1.00  88      2
# 4    0.74  65      2
# ..    ...  ..    ...
# 620  0.93  85      7
# 621  0.91  83      7
# 622  0.94  85      7
# 623  0.91  82      7
# 624  0.92  80      7
#
# [621 rows x 10 columns]

# %% [markdown]
# ## **Construct Data**

# %%
def categorize_shade(h):
    if 0 <= h < 50 or h > 330:
        return "Warm"
    elif 50 <= h < 180:
        return "Cool"
    else:
        return "Neutral"

# %%
df["Shade_Category"] = df["H"].apply(categorize_shade)

# %%
df["Brightness_Ratio"] = df["V"] / 100

# %%
df["Contrast_Score"] = abs(df["S"] - df["L"])

# %%
print(df.head())
# Out:
#         brand brand_short product product_short     hex     H     S     V   L  \
# 0  Maybelline          mb  Fit Me           fmf  f3cfb3  26.0  0.26  0.95  86
# 1  Maybelline          mb  Fit Me           fmf  ffe3c2  32.0  0.24  1.00  92
# 2  Maybelline          mb  Fit Me           fmf  ffe0cd  23.0  0.20  1.00  91
# 3  Maybelline          mb  Fit Me           fmf  ffd3be  19.0  0.25  1.00  88
# 4  Maybelline          mb  Fit Me           fmf  bd9584  18.0  0.30  0.74  65
#
#    group Shade_Category  Brightness_Ratio  Contrast_Score
# 0      2           Warm            0.0095           85.74
# 1      2           Warm            0.0100           91.76
# 2      2           Warm            0.0100           90.80
# 3      2           Warm            0.0100           87.75
# 4      2           Warm            0.0074           64.70

# %% [markdown]
# ## **Data Reduction**

# %%
df = df.drop(["brand_short", "product_short"], axis=1)

# %%
df
# Out:
#           brand     product     hex     H     S     V   L  group  \
# 0    Maybelline      Fit Me  f3cfb3  26.0  0.26  0.95  86      2
# 1    Maybelline      Fit Me  ffe3c2  32.0  0.24  1.00  92      2
# 2    Maybelline      Fit Me  ffe0cd  23.0  0.20  1.00  91      2
# 3    Maybelline      Fit Me  ffd3be  19.0  0.25  1.00  88      2
# 4    Maybelline      Fit Me  bd9584  18.0  0.30  0.74  65      2
# ..          ...         ...     ...   ...   ...   ...  ..    ...
# 620     L'Oréal  True Match  eecfba  24.0  0.22  0.93  85      7
# 621     L'Oréal  True Match  e8c7b8  19.0  0.21  0.91  83      7
# 622     L'Oréal  True Match  f0cbb9  20.0  0.23  0.94  85      7
# 623     L'Oréal  True Match  e9c4b1  20.0  0.24  0.91  82      7
# 624     L'Oréal  True Match  eabea1  24.0  0.31  0.92  80      7
#
#     Shade_Category  Brightness_Ratio  Contrast_Score
# 0             Warm            0.0095           85.74
# 1             Warm            0.0100           91.76
# 2             Warm            0.0100           90.80
# 3             Warm            0.0100           87.75
# 4             Warm            0.0074           64.70
# ..             ...               ...             ...
# 620           Warm            0.0093           84.78
# 621           Warm            0.0091           82.79
# 622           Warm            0.0094           84.77
# 623           Warm            0.0091           81.76
# 624           Warm            0.0092           79.69
#
# [621 rows x 11 columns]

# %% [markdown]
#  Kolom tersebut dihapus karena tidak terlalu penting atau redundant dalam analisis data.

# %% [markdown]
# **Checkpoint 3**

# %% [markdown]
# # **Visualisasi Data yang Relevan**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Pandas/shades.csv")
print(df)
# Out:
#           brand brand_short     product product_short     hex     H     S  \
# 0    Maybelline          mb      Fit Me           fmf  f3cfb3  26.0  0.26
# 1    Maybelline          mb      Fit Me           fmf  ffe3c2  32.0  0.24
# 2    Maybelline          mb      Fit Me           fmf  ffe0cd  23.0  0.20
# 3    Maybelline          mb      Fit Me           fmf  ffd3be  19.0  0.25
# 4    Maybelline          mb      Fit Me           fmf  bd9584  18.0  0.30
# ..          ...         ...         ...           ...     ...   ...   ...
# 620     L'Oréal          lo  True Match           tms  eecfba  24.0  0.22
# 621     L'Oréal          lo  True Match           tms  e8c7b8  19.0  0.21
# 622     L'Oréal          lo  True Match           tms  f0cbb9  20.0  0.23
# 623     L'Oréal          lo  True Match           tms  e9c4b1  20.0  0.24
# 624     L'Oréal          lo  True Match           tms  eabea1  24.0  0.31
#
#         V   L  group
# 0    0.95  86      2
# 1    1.00  92      2
# 2    1.00  91      2
# 3    1.00  88      2
# 4    0.74  65      2
# ..    ...  ..    ...
# 620  0.93  85      7
# 621  0.91  83      7
# 622  0.94  85      7
# 623  0.91  82      7
# 624  0.92  80      7
#
# [625 rows x 10 columns]

# %% [markdown]
# ## **Analisis Variasi Shade 10 Produk dengan Pilihan Warna Terbanyak dan Peluang Pasa**

# %%
plt.figure(figsize=(12,6))
df['brand'].value_counts().head(10).plot(kind='bar', color='skyblue')
plt.title("Top 10 Brand dengan Produk Terbanyak")
plt.xlabel("Brand")
plt.ylabel("Jumlah Produk")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight dari Grafik**

# %% [markdown]
# 1. Beberapa brand memiliki jumlah produk jauh lebih banyak dibanding yang lain.
# 2. Selisih jumlah produk antar brand menunjukkan tingkat persaingan
# 3. Brand dengan lebih banyak produk berpotensi menarik lebih banyak pelanggan.

# %% [markdown]
# **Tindakan yang Bisa Dilakukan**

# %% [markdown]
# 1. Identifikasi kategori  dan warna yang paling diminati
# 2. Brand dengan produk yang lebih sedikit bisa lebih fokus menargetkan pasar tertentu
# 3. Evaluasi produk terlaris untuk meningkatkan efisiensi stok.

# %% [markdown]
# ## **Analisis Visual 10 Produk dengan Variasi Shade Terbanyak dan Potensinya di Pasar**

# %%
shade_per_product = df.groupby('product')['hex'].nunique().sort_values(ascending=False)
plt.figure(figsize=(12,6))
shade_per_product.head(10).plot(kind='bar', color='lightgreen')
plt.title("Top 10 Produk dengan Variasi Shade Terbanyak")
plt.xlabel("Produk")
plt.ylabel("Jumlah Shade Unik")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight dari Grafik**

# %% [markdown]
# 1. Produk tertentu memiliki banyak shade dibandingkan yang lain, menunjukkan tingginya permintaan akan variasi warna.
# 2. Produk dengan sedikit shade mungkin menargetkan pasar yang lebih spesifik atau memiliki keterbatasan dalam variasi warna.
# 3. Produk dengan variasi shade terbanyak cenderung berasal dari kategori yang memerlukan pilihan warna luas.

# %% [markdown]
# **Tindakan yang Bisa Dilakukan:**

# %% [markdown]
# 1. Identifikasi produk dengan shade terbanyak untuk memahami preferensi warna pelanggan.
# 2. Produk dengan sedikit shade bisa menambah variasi.
# 3. Fokus pada produk dengan shade populer untuk meningkatkan penjualan.

# %% [markdown]
# ## **Analisis Visual Heatmap Variasi Shade Berdasarkan Brand dan Grup Produk**

# %%
plt.figure(figsize=(12,6))
heatmap_data = df.pivot_table(index='brand', columns='group', aggfunc='size', fill_value=0)
sns.heatmap(heatmap_data, cmap="Reds", annot=True, fmt="d", linewidths=0.5)
plt.title("Heatmap Variasi Shade Berdasarkan Brand dan Group Produk")
plt.xlabel("Group Produk")
plt.ylabel("Brand")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight dari Grafik**

# %% [markdown]
# 1. Beberapa brand lebih fokus pada grup tertentu, terlihat dari jumlah shade yang tinggi di kategori tertentu.
# 2. Beberapa kategori produk memiliki lebih banyak variasi warna dibandingkan yang lain.
# 3. Brand yang punya sedikit variasi warna mungkin fokus pada pasar tertentu atau hanya menawarkan beberapa produk andalan.

# %% [markdown]
# **Tindakan yang Bisa Dilakukan**

# %% [markdown]
# 1. Brand dengan sedikit pilihan warna bisa mencoba menambah variasi produknya agar lebih beragam.
# 2. Fokus mempromosikan brand dengan banyak pilihan warna agar pelanggan punya lebih banyak opsi.
# 3. Brand dengan variasi warna yang tidak merata bisa menyesuaikan produksinya agar lebih bersaing di pasar.

# %% [markdown]
# ## **Analisis Penyebaran Warna Berdasarkan Nilai Hue"**

# %%
df['H'] = pd.to_numeric(df['H'], errors='coerce')
plt.figure(figsize=(12,6))
sns.histplot(df['H'], bins=20, kde=True, color='purple')
plt.title("Distribusi Warna HEX berdasarkan Nilai Hue")
plt.xlabel("Hue (H)")
plt.ylabel("Frekuensi")
plt.show()

# %% [markdown]
# **Insight dari Grafik**

# %% [markdown]
# 1. Penyebaran Hue tidak merata, menunjukkan ada warna yang lebih banyak dibanding yang lain.
# 2. Menambahkan shade baru di warna yang masih sedikit bisa membantu menjangkau lebih banyak pelanggan.
# 3. Beberapa warna masih jarang tersedia, maka bisa jadi peluang untuk menciptakan shade baru yang lebih inovatif

# %% [markdown]
# **Tindakan yang Bisa Dilakukan**

# %% [markdown]
# 1. Memproduksi lebih banyak warna yang disukai konsumen.
# 2. Menambahkan shade baru di warna yang masih sedikit tersedia agar bisa lebih menarik lebih banyak pelanggan.
# 3. Mempromosikan warnna-warna yang paling populer agar penjualan meningkat.
